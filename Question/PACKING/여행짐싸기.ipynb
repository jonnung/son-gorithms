# %% [markdown]
# ## 여행짐싸기
# 캐리어의 용량이 정해져 있기 때문에 가져갈 수 있는 물건들의 부피 합은 캐리어의 용량 w 이하여야 함.
# 이때 절박도를 최대화할 수 있는 물건들의 목록을 계산하는 프로그램을 작성하라!
#
# ### 입력
# 첫줄은 테스트 케이스의 수 C (1≤C≤50)
# 각 테스트 케이스의 첫번째는 가져가고 싶은 **물건의 수 N (1≤N≤100)**과 **캐리어의 용량 W (1≤W≤1000)**
# 그 후 순서대로 각 물건의 정보가 한줄씩 주어짐.
# 물건에 대한 정보는 **이름, 부피, 절박도** 순서.
# 이름은 공백 없는 알파벳 대소문자 1글자 이상 20글자 이하의 문자열, 부피와 절박도는 1000 이하의 자연수.
# ### 출력
# 각 테스트 케이스별 출력의 첫 줄에는 가져갈 수 있는 물건들의 **최대 절박도 합**과 **가져갈 물건들의 개수**를 출력.
# 그 후 각 줄마다 하나씩 각 물건들의 이름을 출력.
# 만약 절박도를 최대화하는 물건들의 조합이 여럿일 경우 아무 것이나 출력해도 됨.

# %%
n = 6  # 물건의 수
w = 10  # 캐리어 용량

# 물건 정보 [(이름, 부피, 절박도)]
p = [('laptop', 4, 7), ('camera', 2, 10), ('xbox', 6, 6), ('grinder', 4, 7), ('dumbell', 2, 5), ('encyclopedia', 10, 4)]
